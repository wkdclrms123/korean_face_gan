# %% [markdown]
# <a href="https://colab.research.google.com/github/Zzang-yeah/korean_face_gan/blob/main/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Zzang-yeah/korean_face_gan.git
# Out:
# Cloning into 'korean_face_gan'...
# remote: Enumerating objects: 1623, done.
# remote: Counting objects: 100% (1623/1623), done.
# remote: Compressing objects: 100% (1607/1607), done.
# remote: Total 1623 (delta 11), reused 1620 (delta 11), pack-reused 0
# Receiving objects: 100% (1623/1623), 15.33 MiB | 11.44 MiB/s, done.
# Resolving deltas: 100% (11/11), done.

# %%
# !zip -r /content/korean_face_gan/dataset/images_face_only.zip /content/korean_face_gan/dataset/
# Out:
#   adding: content/korean_face_gan/dataset/ (stored 0%)
#   adding: content/korean_face_gan/dataset/images_face_only/ (stored 0%)
#   adding: content/korean_face_gan/dataset/images_face_only/seed_1442.jpg (deflated 2%)
#   adding: content/korean_face_gan/dataset/images_face_only/seed_359.jpg (deflated 2%)
#   adding: content/korean_face_gan/dataset/images_face_only/seed_864.jpg (deflated 2%)
#   adding: content/korean_face_gan/dataset/images_face_only/seed_1383.jpg (deflated 2%)
#   adding: content/korean_face_gan/dataset/images_face_only/seed_1018.jpg (deflated 2%)
#   adding: content/korean_face_gan/dataset/images_face_only/seed_549.jpg (deflated 2%)
#   adding: content/korean_face_gan/dataset/images_face_only/seed_968.jpg (deflated 2%)
#   adding: content/korean_face_gan/dataset/images_face_only/seed_819.jpg (deflated 2%)
#   adding: content/korean_face_gan/dataset/images_face_only/seed_208.jpg (deflated 1%)
# ...

# %%
# !python /content/korean_face_gan/stylegan2-ada-pytorch/dataset_tool.py \
				--source /content/korean_face_gan/dataset/images_face_only.zip \
				--dest /content/korean_face_gan/dataset/test.zip
# Out:
# 100% 1508/1508 [00:09<00:00, 163.80it/s]

# %%
# !python /content/korean_face_gan/stylegan2-ada-pytorch/train.py \
--outdir  /content/korean_face_gan/train_result \
--snap 10 \
--data /content/korean_face_gan/dataset/test.zip \
--augpipe bgcfnc

# %% [markdown]
# !python /content/korean_face_gan/stylegan2-ada-pytorch/train.py \
# --outdir  /content/korean_face_gan/train_result \
# --snap 10 \
# --data /content/korean_face_gan/dataset/test.zip \
# --augpipe bgcfnc

# %%
# !python /content/korean_face_gan/stylegan2-ada-pytorch/generate.py generate-images --help
# Out:
# Usage: generate.py [OPTIONS]
#
#   Generate images using pretrained network
#   pickle.
#
#   Examples:
#
#   # Generate curated MetFaces images without truncation (Fig.10 left)
#   python generate.py --outdir=out --trunc=1 --seeds=85,265,297,849 \
#       --network=https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/metfaces.pkl
#
#   # Generate uncurated MetFaces images with truncation (Fig.12 upper left)
#   python generate.py --outdir=out --trunc=0.7 --seeds=600-605 \
#       --network=https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/metfaces.pkl
#
#   # Generate class conditional CIFAR-10 images (Fig.17 left, Car)
#   python generate.py --outdir=out --seeds=0-35 --class=1 \
#       --network=https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/cifar10.pkl
#
#   # Render an image from projected W
#   python generate.py --outdir=out --projected_w=projected_w.npz \
# ...

# %%
# !pip install ninja
# Out:
# ...
#      |████████████████████████████████| 108 kB 11.5 MB/s
# ...

# %%
# Generate curated MetFaces images without truncation (Fig.10 left)
# !python /content/korean_face_gan/stylegan2-ada-pytorch/generate.py --outdir=out --trunc=1 --seeds=85,265,297,849 \
    --network=https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/metfaces.pkl

# Generate uncurated MetFaces images with truncation (Fig.12 upper left)
# !python /content/korean_face_gan/stylegan2-ada-pytorch/generate.py --outdir=out --trunc=0.7 --seeds=600-605 \
    --network=https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/metfaces.pkl

# Generate class conditional CIFAR-10 images (Fig.17 left, Car)
# !python /content/korean_face_gan/stylegan2-ada-pytorch/generate.py --outdir=out --seeds=0-35 --class=1 \
    --network=https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/cifar10.pkl

# Style mixing example
# !python /content/korean_face_gan/stylegan2-ada-pytorch/style_mixing.py --outdir=out --rows=85,100,75,458,1500 --cols=55,821,1789,293 \
    --network=https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/metfaces.pkl
# Out:
# Loading networks from "https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/metfaces.pkl"...
# Generating image for seed 85 (0/4) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 265 (1/4) ...
# Generating image for seed 297 (2/4) ...
# Generating image for seed 849 (3/4) ...
# Loading networks from "https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/metfaces.pkl"...
# Generating image for seed 600 (0/6) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 601 (1/6) ...
# Generating image for seed 602 (2/6) ...
# Generating image for seed 603 (3/6) ...
# Generating image for seed 604 (4/6) ...
# Generating image for seed 605 (5/6) ...
# Loading networks from "https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/cifar10.pkl"...
# ...

# %%
# !python /content/korean_face_gan/stylegan2-ada-pytorch/projector.py \
--outdir=/content/korean_face_gan/out \
--target=/content/drive/MyDrive/다운로드.png \
--network=/content/korean_face_gan/train_result/00000-test-auto1-bgcfnc/network-snapshot-000000.pkl
# Out:
# Loading networks from "/content/korean_face_gan/train_result/00000-test-auto1-bgcfnc/network-snapshot-000000.pkl"...
# Computing W midpoint and stddev using 10000 samples...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:1051: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return forward_call(*input, **kwargs)
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# step    1/1000: dist 1.06 loss 24567.73
# step    2/1000: dist 1.10 loss 27641.13
# step    3/1000: dist 1.08 loss 27167.51
# step    4/1000: dist 1.12 loss 26250.64
# step    5/1000: dist 1.08 loss 24955.98
# step    6/1000: dist 1.13 loss 23354.92
# step    7/1000: dist 1.11 loss 21510.19
# step    8/1000: dist 1.11 loss 19483.92
# ...
