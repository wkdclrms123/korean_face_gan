# %%
# !git clone https://github.com/NVlabs/stylegan2-ada.git
# Out:
# Cloning into 'stylegan2-ada'...
# remote: Enumerating objects: 71, done.
# remote: Total 71 (delta 0), reused 0 (delta 0), pack-reused 71
# Unpacking objects: 100% (71/71), done.

# %%
cd /content/drive/MyDrive/final_project/bike_stylegan
# Out:
# /content/drive/MyDrive/final_project/bike_stylegan

# %%
# !wget "https://www.dropbox.com/s/0ybsudabqscstf7/biked_dataset.tar.gz"
# Out:
# --2021-08-24 07:13:39--  https://www.dropbox.com/s/0ybsudabqscstf7/biked_dataset.tar.gz
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.6.18, 2620:100:6019:18::a27d:412
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.6.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/0ybsudabqscstf7/biked_dataset.tar.gz [following]
# --2021-08-24 07:13:39--  https://www.dropbox.com/s/raw/0ybsudabqscstf7/biked_dataset.tar.gz
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc12c6e5d0492de1b451f34ecbf3.dl.dropboxusercontent.com/cd/0/inline/BU3Bq4w-1MGwC6VLcy9xuJtO14E7s2tyTi-0PAh8K6kykICRn4abZHOdHrwLXA3Pa1C-Ds5JOr25AOfBxuc163UOj7-OYdGSmLEHOxMSOUvzKt38SZ_kLt3BOIjoCIkSOrfMCo9FZvN97YBlqqyUU0Xh/file# [following]
# ...

# %%
# !tar -zxvf biked_dataset.tar.gz
# Out:
# biked/
# biked/bike (3122).jpg
# biked/bike (4716).jpg
# biked/bike (2791).jpg
# biked/bike (2809).jpg
# biked/bike (1135).jpg
# biked/bike (591).jpg
# biked/bike (1205).jpg
# biked/bike (1557).jpg
# biked/bike (3130).jpg
# biked/bike (1768).jpg
# biked/bike (1625).jpg
# biked/bike (4072).jpg
# biked/bike (2563).jpg
# biked/bike (1407).jpg
# biked/bike (961).jpg
# biked/bike (3213).jpg
# biked/bike (836).jpg
# biked/bike (674).jpg
# biked/bike (2262).jpg
# biked/bike (3010).jpg
# biked/bike (2345).jpg
# biked/bike (3437).jpg
# biked/bike (2675).jpg
# biked/bike (1837).jpg
# biked/bike (31).jpg
# biked/bike (3117).jpg
# biked/bike (2499).jpg
# biked/bike (3529).jpg
# biked/bike (2250).jpg
# biked/bike (572).jpg
# biked/bike (3233).jpg
# biked/bike (2588).jpg
# biked/bike (2300).jpg
# biked/bike (2214).jpg
# biked/bike (253).jpg
# biked/bike (1684).jpg
# biked/bike (4161).jpg
# biked/bike (525).jpg
# biked/bike (831).jpg
# biked/bike (4206).jpg
# biked/bike (3722).jpg
# ...

# %%
# !rm biked_dataset.tar.gz

# %%
# %tensorflow_version 1.x
# !nvidia-smi
# Out:
# TensorFlow 1.x selected.
# Tue Aug 24 08:26:04 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   70C    P8    34W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !python /content/stylegan2-ada/dataset_tool.py create_from_images /content/drive/MyDrive/final_project/bike_stylegan/biked biked
# Out:
# Loading images from "biked"
# Creating dataset "/content/drive/MyDrive/final_project/bike_stylegan/biked"
# /content/stylegan2-ada/dataset_tool.py:96: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   'data': tf.train.Feature(bytes_list=tf.train.BytesList(value=[quant.tostring()]))}))
# Added 290 images.
# Traceback (most recent call last):
#   File "/content/stylegan2-ada/dataset_tool.py", line 993, in <module>
#     execute_cmdline(sys.argv)
#   File "/content/stylegan2-ada/dataset_tool.py", line 988, in execute_cmdline
#     func(**vars(args))
#   File "/content/stylegan2-ada/dataset_tool.py", line 672, in create_from_images
#     img = np.asarray(PIL.Image.open(image_filenames[order[idx]]))
#   File "/usr/local/lib/python3.7/dist-packages/PIL/Image.py", line 2896, in open
#     "cannot identify image file %r" % (filename if filename else fp)
# PIL.UnidentifiedImageError: cannot identify image file 'biked/biked-r05.tfrecords'

# %%
# !python /content/stylegan2-ada/train.py --outdir /content/results --snap=10 --data=/content/drive/MyDrive/final_project/bike_stylegan/biked --augpipe=bgcfnc --res=512
# Out:
# tcmalloc: large alloc 4294967296 bytes == 0x55ab0f490000 @  0x7f9686d73001 0x7f9683fb654f 0x7f9684006b58 0x7f968400ab17 0x7f96840a9203 0x55ab070d20a4 0x55ab070d1da0 0x55ab07146868 0x55ab07141235 0x55ab070d3fec 0x55ab07114bc9 0x55ab07111ac4 0x55ab070d28a9 0x55ab07146b0a 0x55ab07140c35 0x55ab07012e2c 0x55ab07143318 0x55ab07140c35 0x55ab07012e2c 0x55ab07143318 0x55ab07141235 0x55ab07012e2c 0x55ab07143318 0x55ab070d365a 0x55ab07141b0e 0x55ab07140c35 0x55ab07140933 0x55ab0720a402 0x55ab0720a77d 0x55ab0720a626 0x55ab071e2313
# ...

# %%
cd /content/drive/MyDrive/final_project/bike_stylegan
# Out:
# /content/drive/MyDrive/final_project/bike_stylegan

# %%
# !wget "https://www.dropbox.com/s/p51bd1muw11c06m/full-bike-network-snapshot-004096.pkl"
# Out:
# --2021-08-24 08:35:15--  https://www.dropbox.com/s/p51bd1muw11c06m/full-bike-network-snapshot-004096.pkl
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6035:18::a27d:5512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/p51bd1muw11c06m/full-bike-network-snapshot-004096.pkl [following]
# --2021-08-24 08:35:16--  https://www.dropbox.com/s/raw/p51bd1muw11c06m/full-bike-network-snapshot-004096.pkl
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc038eeaebf93c1ecbaebef052ea.dl.dropboxusercontent.com/cd/0/inline/BU3jB754Cw4aRPHlIU6WfP8KvnJLaj5pmD3fv-qKWwbdklkOe1N-pE9LL_oCadmR3KC8TnWSNa9KVPF0j8msDxby8H7yXjNvn0yhZhDoRjC2trd0Wx5M5OMZqHUwBFJQ0oMn1tZsmTTOTNt-X_oVjTND/file# [following]
# ...

# %%
# !python /content/stylegan2-ada/train.py --outdir /content/results --snap=10 --data=/content/drive/MyDrive/final_project/bike_stylegan/biked --augpipe=bgcfnc --res=512 --resume=/content/drive/MyDrive/final_project/bike_stylegan/full-bike-network-snapshot-004096.pkl
# Out:
# tcmalloc: large alloc 4294967296 bytes == 0x55a877f98000 @  0x7fa77885b001 0x7fa775a9e54f 0x7fa775aeeb58 0x7fa775af2b17 0x7fa775b91203 0x55a86fc4c0a4 0x55a86fc4bda0 0x55a86fcc0868 0x55a86fcbb235 0x55a86fc4dfec 0x55a86fc8ebc9 0x55a86fc8bac4 0x55a86fc4c8a9 0x55a86fcc0b0a 0x55a86fcbac35 0x55a86fb8ce2c 0x55a86fcbd318 0x55a86fcbac35 0x55a86fb8ce2c 0x55a86fcbd318 0x55a86fcbb235 0x55a86fb8ce2c 0x55a86fcbd318 0x55a86fc4d65a 0x55a86fcbbb0e 0x55a86fcbac35 0x55a86fcba933 0x55a86fd84402 0x55a86fd8477d 0x55a86fd84626 0x55a86fd5c313
# ...
